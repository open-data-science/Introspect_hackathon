# %%
import asyncio
from aioes import Elasticsearch

# %%
from chunk import TimeDistance
from chunk import Chunker
from slack_data_loader import SlackLoader

# %%
PATH_TO_DATA = './data'

# %%
es = Elasticsearch(['localhost:9200'])

# %%
def gen_synonyms():
    """
    Generate some synonyms in a file. All words separated by comma are treated as equal
    """
    with open("help_data/synonyms.txt", "w") as syns:
        syns.write("xboost, эксгебуст, эксбуст, иксгебуст, xgboost\n")
        syns.write("пыха, пыху, пых, php\n")
        syns.write("lol, лол\n")
        syns.write("питон, python\n")

# %%
index_name = "ods-slack-index"
mapping_name = "thread"
index_body = {
    "settings": {
        "analysis": {
          "filter": {
            "russian_stop": {
              "type":       "stop",
              "stopwords":  "_russian_" 
            },
            "russian_stemmer": {
              "type":       "stemmer",
              "language":   "russian"
            },
            "synonyms_expand": {
              "type": "synonym", 
              # path to synonym file.
              # for ES to be able to read it, security policy should be set as described here:
              # https://stackoverflow.com/questions/35401917/reading-a-file-in-an-elasticsearch-plugin
              "synonyms_path": "/usr/share/config_data/synonyms.txt"
            }
          },
          "analyzer": {
            "russian_syn": {
              "tokenizer":  "standard",
              "filter": [
                "lowercase",
                "russian_stop",
                "russian_stemmer",
                "synonyms_expand"
              ]
            }
          }
        }
    },
    "mappings":{  
        mapping_name:{
          "properties":{
            "channel": {"type": "keyword"},
            "title": {"type":"string", "analyzer":"russian_syn"},
            "ts": {"type": "date"},
            "messages" : {
                "properties":{
                    "text": {"type":"string", "analyzer":"russian_syn"},
                    "user_id": {"type": "keyword"},
                    "user_real_name": {"type":"string"},
                    "ts": {"type": "date"}
                }
            }
          }
        }
    }
}

async def create_index():
    return await es.indices.create(
        index=index_name,
        body=index_body
    )
    
async def check_index_exists():
    return await es.indices.exists(index=index_name)


async def delete_index():
    return await es.delete(index=index_name)

async def openclose():
    """
    Closing and opening index again reloads synomyms file
    """
    await es.indices.close(index=index_name)
    await es.indices.open(index=index_name)
    
async def populate_index(channel, messages):
    await es.index(
        index=index_name,
        doc_type=mapping_name,
        body={
            "channel": channel,
            "title": messages[0]['text'],
            "ts": messages[0]['ts'] * 1000,
            "messages": messages
        }
    )

async def query_index(query):
    return await es.search(
        index=index_name,
        doc_type=mapping_name,
        body={
            "query":{
                "multi_match" : {
                  "fields" : [ "title^3", "messages.text" ],
                  "query": query
                }
            }
        }
    )

# %%
loop = asyncio.get_event_loop()

# %%
if loop.run_until_complete(check_index_exists()):
    print(loop.run_until_complete(delete_index()))
    
print(loop.run_until_complete(create_index()))
# Out:
# {'acknowledged': True}
# {'acknowledged': True, 'shards_acknowledged': True}

# %%
# reload synonims without recreating the whole database
gen_synonyms()
loop.run_until_complete(openclose())

# %%
async def index_channel(channel = "nlp"):
    data = SlackLoader(PATH_TO_DATA, only_channels=[channel])
    chunker = Chunker()
    groups  = chunker.get_groups(data)
    
    print("Indexing: " + channel)

    workers = []
    for g in groups:
        users = data.users
        for msg in g:
            if msg['user'] in users:
                msg['user_real_name'] = users[msg['user']]['name']
            if 'dt' in msg:
                del msg['dt']
            msg['timestamp'] = str(msg['ts'])
            msg['ts'] = int(msg['ts'])
            if "attachments" in msg:
                for attach in msg["attachments"]:
                    if 'ts' in attach:
                        attach['ts'] = float(attach['ts'])
        workers.append(
            asyncio.ensure_future(populate_index(channel, g))
        )
    return await asyncio.gather(*workers)

async def index_channels(channels):
    await asyncio.gather(
        *[asyncio.ensure_future(index_channel(channel)) for channel in channels]
    )

# %%
useful_channels = ["nlp", "deep_learning", "datasets",
                  "sequences_series", "bayesian", "_meetings", "edu_academy",
                  "edu_books", "visualization", "hardware",
                  "reinforcement_learnin", "theory_and_practice"]

loop.run_until_complete(index_channels(useful_channels))
# Out:
# Indexing: nlp
# Indexing: deep_learning
# Indexing: datasets
# Indexing: sequences_series
# Indexing: bayesian
# Indexing: _meetings
# Indexing: edu_academy
# Indexing: edu_books
# Indexing: visualization
# Indexing: hardware
# Indexing: reinforcement_learnin
# Indexing: theory_and_practice

# %%
loop.run_until_complete(query_index("как использовать xgboost в python"))
# Out:
# {'_shards': {'failed': 0, 'successful': 5, 'total': 5},
#  'hits': {'hits': [{'_id': 'AVwqss9ZXdpNESzK4vJq',
#     '_index': 'ods-slack-index',
#     '_score': 46.286835,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'text': 'посоны, а есть ли в природе враппер  xgboost для других языков, помимо R/Python?',
#        'timestamp': '1469368019.00038',
#        'ts': 1469368019,
#        'type': 'message',
#        'user': 'U0U2ENJ4U',
#        'user_real_name': 'andrey'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 2,
#          'name': 'trollface',
#          'users': ['U1CGKK865', 'U04CH4QBD']}],
#        'text': 'c++',
#        'timestamp': '1469368047.000381',
#        'ts': 1469368047,
#        'type': 'message',
#        'user': 'U0FEJNBGQ',
#        'user_real_name': 'mabrek'},
#       {'channel': 'C047H3DP4',
#        'text': 'вроде как для java тоже пилили',
#        'timestamp': '1469368269.000382',
#        'ts': 1469368269,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'attachments': [{'fallback': 'GitHub: dmlc/xgboost',
#          'from_url': 'https://github.com/dmlc/xgboost/tree/master/jvm-packages',
#          'id': 1,
#          'service_icon': 'https://github.com/apple-touch-icon.png',
#          'service_name': 'GitHub',
#          'text': 'xgboost - Scalable, Portable and Distributed Gradient Boosting (GBDT, GBRT or GBM) Library, for Python, R, Java, Scala, C++ and more. Runs on single machine, Hadoop, Spark, Flink and DataFlow',
#          'thumb_height': 227,
#          'thumb_url': 'https://avatars0.githubusercontent.com/u/11508361?v=3&s=400',
#          'thumb_width': 227,
#          'title': 'dmlc/xgboost',
#          'title_link': 'https://github.com/dmlc/xgboost/tree/master/jvm-packages'}],
#        'channel': 'C047H3DP4',
#        'text': '<https://github.com/dmlc/xgboost/tree/master/jvm-packages>',
#        'timestamp': '1469368295.000383',
#        'ts': 1469368295,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'}],
#      'title': 'посоны, а есть ли в природе враппер  xgboost для других языков, помимо R/Python?',
#      'ts': 1469368019000},
#     '_type': 'thread'},
#    {'_id': 'AVwqstVtXdpNESzK4vPj',
#     '_index': 'ods-slack-index',
#     '_score': 40.112915,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'text': 'кто-нибудь использовал "count:poisson" в xgboost? у меня при попытке ее использовать сразу же отовсюду лезут наны',
#        'timestamp': '1487263682.005804',
#        'ts': 1487263682,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': 'мой target - это флоат с целым числом внутри, пытался перевести это в int, не помогло',
#        'timestamp': '1487264067.005805',
#        'ts': 1487264067,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'}],
#      'title': 'кто-нибудь использовал "count:poisson" в xgboost? у меня при попытке ее использовать сразу же отовсюду лезут наны',
#      'ts': 1487263682000},
#     '_type': 'thread'},
#    {'_id': 'AVwqss9VXdpNESzK4vJp',
#     '_index': 'ods-slack-index',
#     '_score': 37.39753,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'attachments': [{'fallback': 'Analytics Vidhya: Complete Guide to Parameter Tuning in XGBoost (with codes in Python)',
#          'from_url': 'http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/',
#          'id': 1,
#          'service_name': 'Analytics Vidhya',
#          'text': 'This article explains the parameter tuning in xgboost model in python and takes a practice problem for practice in data science and analytics',
#          'thumb_height': 280,
#          'thumb_url': 'http://www.analyticsvidhya.com/wp-content/uploads/2016/03/article.jpg',
#          'thumb_width': 500,
#          'title': 'Complete Guide to Parameter Tuning in XGBoost (with codes in Python)',
#          'title_link': 'http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/',
#          'ts': 1456819200.0}],
#        'channel': 'C047H3DP4',
#        'text': '<http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/>',
#        'timestamp': '1469307949.000368',
#        'ts': 1469307949,
#        'type': 'message',
#        'user': 'U0U2ENJ4U',
#        'user_real_name': 'andrey'},
#       {'attachments': [{'author_icon': 'https://secure.gravatar.com/avatar/28ec7013c3d5b5cbd9633d12c1407eff.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0003-48.png',
#          'author_link': 'https://opendatascience.slack.com/team/ololo',
#          'author_name': 'Alexey Grigorev',
#          'author_subname': 'ololo',
#          'channel_id': 'C040HKJF1',
#          'channel_name': '_random_flood',
#          'fallback': '[July 21st, 2016 12:51 PM] ololo: вот такое есть, <https://www.kaggle.com/c/bnp-paribas-cardif-claims-management/forums/t/19083/best-practices-for-parameter-tuning-on-models/108783#post108783>\nно мне как-то не особо помогало, видимо руки кривые',
#          'footer': 'Posted in #_random_flood',
#          'from_url': 'https://opendatascience.slack.com/archives/_random_flood/p1469130686000641',
#          'id': 1,
#          'is_msg_unfurl': True,
#          'mrkdwn_in': ['text'],
#          'text': 'вот такое есть, <https://www.kaggle.com/c/bnp-paribas-cardif-claims-management/forums/t/19083/best-practices-for-parameter-tuning-on-models/108783#post108783>\nно мне как-то не особо помогало, видимо руки кривые',
#          'ts': 1469130686.000641}],
#        'channel': 'C047H3DP4',
#        'text': '<@U0U2ENJ4U>: в <#C040HKJF1> было небольшое обсуждение про подбора гиперпараметров xgboost совсем недавно.\nвот ещё например статья: <https://opendatascience.slack.com/archives/_random_flood/p1469130686000641>',
#        'timestamp': '1469308112.00037',
#        'ts': 1469308112,
#        'type': 'message',
#        'user': 'U0AF2AZCM',
#        'user_real_name': 'valeriy.ischenko'},
#       {'channel': 'C047H3DP4',
#        'text': 'вот я как раз по следам обсуждения вспомнил, что статью такую находил..',
#        'timestamp': '1469308143.000372',
#        'ts': 1469308143,
#        'type': 'message',
#        'user': 'U0U2ENJ4U',
#        'user_real_name': 'andrey'},
#       {'channel': 'C047H3DP4',
#        'text': 'там на неё тоже ссылка была',
#        'timestamp': '1469308162.000373',
#        'ts': 1469308162,
#        'type': 'message',
#        'user': 'U0AF2AZCM',
#        'user_real_name': 'valeriy.ischenko'},
#       {'attachments': [{'author_icon': 'https://secure.gravatar.com/avatar/843236b6072be82ea05015f0006aa2cb.jpg?s=48&d=https%3A%2F%2Fa.slack-edge.com%2F66f9%2Fimg%2Favatars%2Fava_0019-48.png',
#          'author_link': 'https://opendatascience.slack.com/team/valeriy.ischenko',
#          'author_name': 'Valeriy Ischenko',
#          'author_subname': 'valeriy.ischenko',
#          'channel_id': 'C040HKJF1',
#          'channel_name': '_random_flood',
#          'fallback': '[July 21st, 2016 12:52 PM] valeriy.ischenko: статей есть много. вот ещё например: <http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/>',
#          'footer': 'Posted in #_random_flood',
#          'from_url': 'https://opendatascience.slack.com/archives/_random_flood/p1469130727000643',
#          'id': 1,
#          'is_msg_unfurl': True,
#          'mrkdwn_in': ['text'],
#          'text': 'статей есть много. вот ещё например: <http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/>',
#          'ts': 1469130727.000643}],
#        'channel': 'C047H3DP4',
#        'edited': {'ts': '1469308271.000000', 'user': 'U0AF2AZCM'},
#        'text': '<https://opendatascience.slack.com/archives/_random_flood/p1469130727000643>\nно <@U0DA4J82H> писал, что из статьи, что он кинул у него советы лучше зашли',
#        'timestamp': '1469308251.000374',
#        'ts': 1469308251,
#        'type': 'message',
#        'user': 'U0AF2AZCM',
#        'user_real_name': 'valeriy.ischenko'},
#       {'attachments': [{'fallback': 'How to tune hyperparameters of xgboost trees?',
#          'from_url': 'https://stats.stackexchange.com/questions/171043/how-to-tune-hyperparameters-of-xgboost-trees',
#          'id': 1,
#          'service_icon': 'http://cdn.sstatic.net/Sites/stats/img/favicon.ico?v=573163e34adf',
#          'service_name': 'stats.stackexchange.com',
#          'text': 'I have a class imbalanced data &amp; I want to tune the hyperparameters of the boosted tress using xgboost. QuestionsIs there an equivalent of gridsearchcv or randomsearchcv forxgboost?If no...',
#          'thumb_height': 316,
#          'thumb_url': 'https://cdn.sstatic.net/Sites/stats/img/apple-touch-icon@2.png?v=344f57aa10cc&a',
#          'thumb_width': 316,
#          'title': 'How to tune hyperparameters of xgboost trees?',
#          'title_link': 'https://stats.stackexchange.com/questions/171043/how-to-tune-hyperparameters-of-xgboost-trees'},
#         {'fallback': 'Hypertuning XGBoost parameters',
#          'from_url': 'https://datascience.stackexchange.com/questions/9364/hypertuning-xgboost-parameters/9368#9368',
#          'id': 2,
#          'service_icon': 'http://cdn.sstatic.net/Sites/datascience/img/favicon.ico?v=6fd4da7d1890',
#          'service_name': 'datascience.stackexchange.com',
#          'text': 'XGBoost have been doing a great job, when it comes to dealing with both categorical and continuous dependant variables. But, how do I select the optimized parameters for an XGBoost problem?This i...',
#          'thumb_height': 158,
#          'thumb_url': 'https://cdn.sstatic.net/Sites/datascience/img/apple-touch-icon.png?v=a67b87793e92&a',
#          'thumb_width': 158,
#          'title': 'Hypertuning XGBoost parameters',
#          'title_link': 'https://datascience.stackexchange.com/questions/9364/hypertuning-xgboost-parameters/9368#9368'}],
#        'channel': 'C047H3DP4',
#        'reactions': [{'count': 1, 'name': '+1', 'users': ['U1H5AN1BJ']}],
#        'text': 'Вот пара ссылок для R: <https://stats.stackexchange.com/questions/171043/how-to-tune-hyperparameters-of-xgboost-trees>\n<https://datascience.stackexchange.com/questions/9364/hypertuning-xgboost-parameters/9368#9368>',
#        'timestamp': '1469309013.000377',
#        'ts': 1469309013,
#        'type': 'message',
#        'user': 'U041LH06L',
#        'user_real_name': 'semenoffalex'}],
#      'title': '<http://www.analyticsvidhya.com/blog/2016/03/complete-guide-parameter-tuning-xgboost-with-codes-python/>',
#      'ts': 1469307949000},
#     '_type': 'thread'},
#    {'_id': 'AVwqstlcXdpNESzK4vUW',
#     '_index': 'ods-slack-index',
#     '_score': 33.85201,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'replies': [{'ts': '1494493575.158652', 'user': 'U0DA4J82H'},
#         {'ts': '1494496118.820686', 'user': 'U2F68DB26'},
#         {'ts': '1494496345.878622', 'user': 'U0DA4J82H'},
#         {'ts': '1494496457.907385', 'user': 'U0DA4J82H'},
#         {'ts': '1494496687.965888', 'user': 'U0FEJNBGQ'},
#         {'ts': '1494496771.987025', 'user': 'U0DA4J82H'}],
#        'reply_count': 6,
#        'text': 'чат, а никому в последнее время не приходилось задачами ранжирования заниматься? что использовали? может кто-то сравнивал xgboost и LightGBM?',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494491224.528089',
#        'ts': 1494491224,
#        'type': 'message',
#        'unread_count': 6,
#        'user': 'U2F68DB26',
#        'user_real_name': 'xelibrion'},
#       {'channel': 'C047H3DP4',
#        'parent_user_id': 'U2F68DB26',
#        'text': 'У меня часть на лог регрессии, часть на xgb',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494493575.158652',
#        'ts': 1494493575,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'parent_user_id': 'U2F68DB26',
#        'text': '<@U0DA4J82H> на регресии я так понимаю pointwise?',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494496118.820686',
#        'ts': 1494496118,
#        'type': 'message',
#        'user': 'U2F68DB26',
#        'user_real_name': 'xelibrion'},
#       {'channel': 'C047H3DP4',
#        'parent_user_id': 'U2F68DB26',
#        'text': 'ага, pointwise, оно обычно не намного хуже работает',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494496345.878622',
#        'ts': 1494496345,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'parent_user_id': 'U2F68DB26',
#        'text': 'В xgb я тоже обычно pointwise делаю, выигрыш от pairwise обычно не очень большой, если вообще есть',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494496457.907385',
#        'ts': 1494496457,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'parent_user_id': 'U2F68DB26',
#        'text': 'где про pointwise ранжирование почитать? или это просто вероятности тюненого под auc логрега?',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494496687.965888',
#        'ts': 1494496687,
#        'type': 'message',
#        'user': 'U0FEJNBGQ',
#        'user_real_name': 'mabrek'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1494496804.000000', 'user': 'U0DA4J82H'},
#        'parent_user_id': 'U2F68DB26',
#        'text': 'ага, это оно и есть, но смотреть можно не только auc, но еще и map@k и прочее',
#        'thread_ts': '1494491224.528089',
#        'timestamp': '1494496771.987025',
#        'ts': 1494496771,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'}],
#      'title': 'чат, а никому в последнее время не приходилось задачами ранжирования заниматься? что использовали? может кто-то сравнивал xgboost и LightGBM?',
#      'ts': 1494491224000},
#     '_type': 'thread'},
#    {'_id': 'AVwqstDRXdpNESzK4vLA',
#     '_index': 'ods-slack-index',
#     '_score': 33.777863,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'text': 'можно ли сохранить модель в файл в R и прочитать и использовать в питоне?',
#        'timestamp': '1472912199.000017',
#        'ts': 1472912199,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': 'Да',
#        'timestamp': '1472913183.000018',
#        'ts': 1472913183,
#        'type': 'message',
#        'user': 'U0ZHHV83C',
#        'user_real_name': 'vlad'},
#       {'channel': 'C047H3DP4',
#        'text': 'ой я забыл указать, что модель xgboost',
#        'timestamp': '1472913214.000019',
#        'ts': 1472913214,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': 'сорри, закрутился тут',
#        'timestamp': '1472913220.00002',
#        'ts': 1472913220,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': 'Можно)',
#        'timestamp': '1472913221.000021',
#        'ts': 1472913221,
#        'type': 'message',
#        'user': 'U0ZHHV83C',
#        'user_real_name': 'vlad'},
#       {'channel': 'C047H3DP4',
#        'text': 'круто! спасибо',
#        'timestamp': '1472913234.000022',
#        'ts': 1472913234,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': 'Только надо, чтоб имена колонок совпадали, чтоб правильно работало',
#        'timestamp': '1472913255.000023',
#        'ts': 1472913255,
#        'type': 'message',
#        'user': 'U0ZHHV83C',
#        'user_real_name': 'vlad'},
#       {'channel': 'C047H3DP4',
#        'text': 'ок, это легко',
#        'timestamp': '1472913296.000024',
#        'ts': 1472913296,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0FEJNBGQ> а какой-нибудь VAR?',
#        'timestamp': '1472917329.000026',
#        'ts': 1472917329,
#        'type': 'message',
#        'user': 'U1L8WN1J5',
#        'user_real_name': 'sirorezka'},
#       {'channel': 'C047H3DP4',
#        'text': 'в принципе, эту проблему можно запихать в VAR, но кажется некоторым abuse. Получалось ли что-то хорошее таким способом?',
#        'timestamp': '1472917728.000027',
#        'ts': 1472917728,
#        'type': 'message',
#        'user': 'U0FEJNBGQ',
#        'user_real_name': 'mabrek'},
#       {'channel': 'C047H3DP4',
#        'text': 'Ну, для подобных целей не использовал. Моделировал persistence эффекты а рекламе. Там как раз рекомендуют для коррелирующих рядов. Но по сути получились те же две регрессии. ',
#        'timestamp': '1472924852.000028',
#        'ts': 1472924852,
#        'type': 'message',
#        'user': 'U1L8WN1J5',
#        'user_real_name': 'sirorezka'}],
#      'title': 'можно ли сохранить модель в файл в R и прочитать и использовать в питоне?',
#      'ts': 1472912199000},
#     '_type': 'thread'},
#    {'_id': 'AVwqss_lXdpNESzK4vKO',
#     '_index': 'ods-slack-index',
#     '_score': 27.753101,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'edited': {'ts': '1470761600.000000', 'user': 'U1LJE9MCK'},
#        'text': 'Правильно ли понимаю, что если у нас есть набор фич: f1, .., fn, на которых XGBoost строит определённый набор деревьев при заданных параметрах, то если вместо fn использовать g(fn), где g() - строго монотонная функция, тогда у нас результат будет тем же, причём деревья будут "совпадать" (при тех же параметрах), кроме условий в узлах. \nВерно или где-то ошибся?',
#        'timestamp': '1470761592.001218',
#        'ts': 1470761592,
#        'type': 'message',
#        'user': 'U1LJE9MCK',
#        'user_real_name': 'boris'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 4,
#          'name': '+1',
#          'users': ['U1LJE9MCK', 'U1FLG6YR1', 'U041SH27M', 'U0M5S4EN6']}],
#        'text': 'Должно быть верно, деревья нечувствительны к монотонным преобразованиям фичей',
#        'timestamp': '1470761715.00122',
#        'ts': 1470761715,
#        'type': 'message',
#        'user': 'U04ELQZAU',
#        'user_real_name': 'asobolev'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U04ELQZAU>: а где можно пруд почитать? похоже на правду конечно, но я немного отделаться от картинки в голове типа такой',
#        'timestamp': '1470764938.001221',
#        'ts': 1470764938,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'тут не для дерева конечно, но кажется что в таком духе можно разъехаться так чтобы сплиты поменялись',
#        'timestamp': '1470765031.001223',
#        'ts': 1470765031,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'а, сорян, такая картинка это если преобразование над одной фичей сделать, а не над всеми',
#        'timestamp': '1470765063.001224',
#        'ts': 1470765063,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'тогда не надо пруфов',
#        'timestamp': '1470765069.001225',
#        'ts': 1470765069,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'я над одной и предлагаю сделать',
#        'timestamp': '1470765168.001226',
#        'ts': 1470765168,
#        'type': 'message',
#        'user': 'U1LJE9MCK',
#        'user_real_name': 'boris'},
#       {'channel': 'C047H3DP4',
#        'text': 'но там не важно, хоть над одной, хоть над всеми, хоть над десятком',
#        'timestamp': '1470765193.001227',
#        'ts': 1470765193,
#        'type': 'message',
#        'user': 'U1LJE9MCK',
#        'user_real_name': 'boris'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 2,
#          'name': 'levenchuk',
#          'users': ['U0JHK9001', 'U1FLG6YR1']}],
#        'text': 'почему? Другими словами вы разрешаете делать разные монотонные преобразования над фичами и утверждаете, что порядок сплитов и по каким переменным каждый сплит сохранится?   Хотелось бы почитать доказательство. Если на шаге i выбрана таже фича для сплита, что в исходном дереве, то вопросов нет. Но почему будет выбрана имена она?',
#        'timestamp': '1470765678.001228',
#        'ts': 1470765678,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'наверное потому что сплит делается так, чтобы максимизировать information gain или подобное, а эта характеристика считается из значения таргет',
#        'timestamp': '1470765943.001229',
#        'ts': 1470765943,
#        'type': 'message',
#        'user': 'U07JH63AA',
#        'user_real_name': 'omikad'},
#       {'channel': 'C047H3DP4',
#        'text': 'в формуле значения фич вообще нет, только как условие сплита',
#        'timestamp': '1470765971.00123',
#        'ts': 1470765971,
#        'type': 'message',
#        'user': 'U1LJE9MCK',
#        'user_real_name': 'boris'},
#       {'channel': 'C047H3DP4',
#        'text': 'в идеале ничего не изменится, но по факту если сплиты ставятся между наблюдениями, то может меняться скор на тестовом множестве при разных преобразованиях',
#        'timestamp': '1470766208.001231',
#        'ts': 1470766208,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 2,
#          'name': 'heavy_plus_sign',
#          'users': ['U0AS548A1', 'U04ELQZAU']}],
#        'text': 'есть точка, значение которой по этой фиче есть только в тесте и она падает между двумя тренировочными, то разными преобразованиями можно сохраняя монотонность загонять её в разные листья',
#        'timestamp': '1470766251.001232',
#        'ts': 1470766251,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': 'это уже следующий шаг; при тренировке всё будет также',
#        'timestamp': '1470766344.001233',
#        'ts': 1470766344,
#        'type': 'message',
#        'user': 'U1LJE9MCK',
#        'user_real_name': 'boris'},
#       {'channel': 'C047H3DP4',
#        'text': 'чёт сложно сходу прикинуть, обычно среднее между двумя точками трейна берут как сплит\nчисто из-за округлений чтоли в разные попадёт? :thinking_face:',
#        'timestamp': '1470766468.001234',
#        'ts': 1470766468,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470766599.000000', 'user': 'U065VP6F7'},
#        'reactions': [{'count': 4,
#          'name': '+1',
#          'users': ['U0JHK9001', 'U0DA4J82H', 'U04ELQZAU', 'U1FLG6YR1']}],
#        'text': 'да нет, например в трейне есть точки в 0 и в 1 и оптимальный сплит между ними, а в тесте - в .45, если возьмём корень от фичи, она уедет в ~.67, и тогда сплит, который и там и там стоял бы на точке .5 будет её кидать в разные стороны с и без корня',
#        'timestamp': '1470766558.001235',
#        'ts': 1470766558,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470766889.000000', 'user': 'U0AS548A1'},
#        'reactions': [{'count': 1,
#          'name': 'heavy_plus_sign',
#          'users': ['U04ELQZAU']}],
#        'text': 'Да, я понял. Вроде действительно важно, только чтобы отношение порядка внутри каждой фича сохранялось',
#        'timestamp': '1470766881.001238',
#        'ts': 1470766881,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'Для тренировки',
#        'timestamp': '1470766931.00124',
#        'ts': 1470766931,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'а для теста <@U065VP6F7> правильно сказал',
#        'timestamp': '1470766941.001241',
#        'ts': 1470766941,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'может привести к нехорошему на кроссвалидации',
#        'timestamp': '1470766954.001242',
#        'ts': 1470766954,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'правда ситуация должна быть сильно экзотическая',
#        'timestamp': '1470766974.001243',
#        'ts': 1470766974,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 2,
#          'name': 'heavy_plus_sign',
#          'users': ['U04ELQZAU', 'U1FLG6YR1']}],
#        'text': 'ну тут колебания на уровне шума',
#        'timestamp': '1470766989.001244',
#        'ts': 1470766989,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': "это, ребятушки, выручайте, если надо классифицировать текстовые данные, которых достаточно много (сотни тысяч), на тысячи классов (2-3 тысячи), то что бы вы выбрали в такой ситуации (в итоге все должно работать на проде)? Если смотреть в сторону randomforest'a (и extratrees), то он работает более-менее по точности, но сама моделька весит гигабайты (1-2Гб в зависимости от высоты деревьев), что не очень то радует... посмотреть в сторону сеток?  Буду рад, если кто-то поделится советом.",
#        'timestamp': '1470767220.001245',
#        'ts': 1470767220,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 1,
#          'name': 'heavy_plus_sign',
#          'users': ['U04ELQZAU']}],
#        'text': 'А чем плоха модель в 1 ГБ? В память лезет легко',
#        'timestamp': '1470767328.001246',
#        'ts': 1470767328,
#        'type': 'message',
#        'user': 'U0KQ5M6KX',
#        'user_real_name': 'roman-kh'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 1,
#          'name': 'heavy_plus_sign',
#          'users': ['U064DRUF4']}],
#        'text': 'обычная лин. модель как себе ведёт?',
#        'timestamp': '1470767337.001247',
#        'ts': 1470767337,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': '1-2Гб это мало, но я бы с линейных моделей начал, конечно',
#        'timestamp': '1470767359.001248',
#        'ts': 1470767359,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': 'насчет тысяч классов - не знаю)',
#        'timestamp': '1470767393.001249',
#        'ts': 1470767393,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0KQ5M6KX>: да, но если это все дело параллелить, то понадобится уже куда больше Гб, да и вот как раз интересуюсь, вдруг посоветуют что, так то да, для начала и этот вариант покатит',
#        'timestamp': '1470767416.00125',
#        'ts': 1470767416,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U064DRUF4>: линейные пробовал достаточно давно, надо прогнать еще разок',
#        'timestamp': '1470767500.001251',
#        'ts': 1470767500,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'из коробки про тысячи классов ничего не видел, тоже интересно - либо брутфорсом решать, либо всякие иерархии делать и по шагам предсказывать, либо на что-то более хитрое смотреть',
#        'timestamp': '1470767525.001252',
#        'ts': 1470767525,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U064DRUF4>: да, если мне не изменяет память, то линейные немного проигрывают рф, но завтра еще посмотрю',
#        'timestamp': '1470767564.001253',
#        'ts': 1470767564,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'а что на счет сеток?',
#        'timestamp': '1470767585.001254',
#        'ts': 1470767585,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну можно сетки, но линейный svm классификатор либо лог. регрессия на tf*idf фичах, возможно - с обрезанием слов по min_df=2/3/4 + возможно, биграммы - это довольно сильный baseline',
#        'timestamp': '1470767734.001255',
#        'ts': 1470767734,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U064DRUF4>: хм, ладно, завтра еще раз попробую линейные модели потестить',
#        'timestamp': '1470767803.001256',
#        'ts': 1470767803,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'Я ненастоящий сварщик, но кажется сетки будут сильно дольше работать. там ведь надо матрицы умножать  это сложна. А для дерева кажется что надо просто держать деревья поиска по каждой фиче и когда приходит текст на классификацию в каждое его вставить это проста',
#        'timestamp': '1470767844.001257',
#        'ts': 1470767844,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0AS548A1>: да, предикт у 2Гб модели рф очень быстрый, CPU times: user 2 µs, sys: 0 ns, total: 2 µs Wall time: 5.01 µs на один объект',
#        'timestamp': '1470767902.001258',
#        'ts': 1470767902,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'вот, например, статья с сетками, тексты классифицируют: <http://arxiv.org/pdf/1509.01626v3.pdf> - даже там в половине случаев logistic regression + tf*idf все хитрые штуки уделывает',
#        'timestamp': '1470767913.001259',
#        'ts': 1470767913,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': 'а большие тексты?',
#        'timestamp': '1470767928.00126',
#        'ts': 1470767928,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470767960.000000', 'user': 'U0FL6RNHM'},
#        'text': 'нет, маленькие',
#        'timestamp': '1470767949.001261',
#        'ts': 1470767949,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну фича же одни и теже считать, так что размер текста на выбор метода не влияет',
#        'timestamp': '1470767966.001263',
#        'ts': 1470767966,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'достаточно странно, что особо никто такие задачи не решал.. хотя ведь многие тексты классифицируют в разных областях',
#        'timestamp': '1470768013.001264',
#        'ts': 1470768013,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'влияет, для твитов и тд вроде часто tf*idf не используют',
#        'timestamp': '1470768018.001265',
#        'ts': 1470768018,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': 'а просто любопытно: что за 3к классов для текстов?',
#        'timestamp': '1470768045.001266',
#        'ts': 1470768045,
#        'type': 'message',
#        'user': 'U040M0W0S',
#        'user_real_name': 'i'},
#       {'channel': 'C047H3DP4',
#        'text': 'vw можно ещё попробовать, кинуть ему BoW и с параметрами поиграться, он сам нграммы умеет, снижать размерности и т.д.',
#        'timestamp': '1470768081.001267',
#        'ts': 1470768081,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': 'товары, категории товаров',
#        'timestamp': '1470768084.001268',
#        'ts': 1470768084,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': '<http://arxiv.org/abs/1607.01759> - эти парни плохого не посоветуют',
#        'timestamp': '1470768086.001269',
#        'ts': 1470768086,
#        'type': 'message',
#        'user': 'U04FHEY0M',
#        'user_real_name': 'pavel_k'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U04FHEY0M>: thx, посмотрю',
#        'timestamp': '1470768125.00127',
#        'ts': 1470768125,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0FL6RNHM> интересно, а у вас тексты случаем не кластеризуются? если каким-нибудь кминс разбить вектора на эти же 3к кластеров, сильно хуже будет?',
#        'timestamp': '1470768140.001271',
#        'ts': 1470768140,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': 'то что по ссылке можно в vw делать, сами авторы статьи даже об этом говорили',
#        'timestamp': '1470768151.001272',
#        'ts': 1470768151,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U04FHEY0M>: а, это которые на vw в одну строчку?)',
#        'timestamp': '1470768153.001273',
#        'ts': 1470768153,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': 'они-они',
#        'timestamp': '1470768162.001274',
#        'ts': 1470768162,
#        'type': 'message',
#        'user': 'U04FHEY0M',
#        'user_real_name': 'pavel_k'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U1BAKQH2M>: хм, да, кластеризовать я пробовал, но так это же одно и то же по сути',
#        'timestamp': '1470768192.001275',
#        'ts': 1470768192,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 1,
#          'name': 'thinking_face',
#          'users': ['U040M0W0S']}],
#        'text': '3к категорий все-таки многовато, лучше что-то с этим подумать',
#        'timestamp': '1470768204.001276',
#        'ts': 1470768204,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'text': 'если задача, например, подсказать хештег, то классов  легко больше 3к',
#        'timestamp': '1470768254.001277',
#        'ts': 1470768254,
#        'type': 'message',
#        'user': 'U04FHEY0M',
#        'user_real_name': 'pavel_k'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U064DRUF4>: да, если не взлетит идея с одним классификатором, то там есть куда думать, но для начала хочется разобраться с одной моделькой',
#        'timestamp': '1470768270.001278',
#        'ts': 1470768270,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну скорее всего ничего не кластеризуется, т.к. слишком многомерное пространство, но если вдруг каким-то чудом кластеризация k means боль-менее совпадет с классификацией - можно оценивать класс вообще моментально, просто ближайший центроид нашел и все',
#        'timestamp': '1470768289.001279',
#        'ts': 1470768289,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U064DRUF4>: так то там можно рассматривать задачу иерархической классификации и строить уже не одну модель, а совокупность, но, как мне кажется, это куда сложнее и муторней',
#        'timestamp': '1470768313.00128',
#        'ts': 1470768313,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'это да, всякие nce / hierarchical softmax пилить что-ли, или structured output использовать, который явно иерархию учитывает. самому интересно, что тут сделать можно, и как это по-нормальному делать',
#        'timestamp': '1470768335.001281',
#        'ts': 1470768335,
#        'type': 'message',
#        'user': 'U064DRUF4',
#        'user_real_name': 'kmike'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 2,
#          'name': 'sleuth_or_spy',
#          'users': ['U0JHK9001', 'U049HDR2Z']}],
#        'text': 'типа подсказываете категорию на основе описания? а это не авито конкурс?))',
#        'timestamp': '1470768350.001282',
#        'ts': 1470768350,
#        'type': 'message',
#        'user': 'U040M0W0S',
#        'user_real_name': 'i'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470768815.000000', 'user': 'U0AS548A1'},
#        'text': '<@U1BAKQH2M>: это не сильно от RF отличается, быстрее, но мне кажется неуловимо. Вместо несколько деревьев в одно вставить надо [это все про knn сорян]',
#        'timestamp': '1470768377.001283',
#        'ts': 1470768377,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну примерно, но не авито',
#        'timestamp': '1470768381.001284',
#        'ts': 1470768381,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'хотя конечно если там времени пока грузится страничка, то надо сокращать как только можно',
#        'timestamp': '1470768544.001286',
#        'ts': 1470768544,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'Зачем k-means, когда можно топик модель?',
#        'timestamp': '1470768561.001287',
#        'ts': 1470768561,
#        'type': 'message',
#        'user': 'U1FLG6YR1',
#        'user_real_name': 'hushpar'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0AS548A1> это принципиально отличается от рф тем, что позволяет хранить не 2гб деревьев, а 3к векторов. Там проблема будет в том, что эта дичь сработает только если каким-то чудом все классы локализованы в пространстве, чтоб каждый из них в свой кластер собрался. Это как-то маловероятно, как мне кажется, но если есть векторизованные тексты - попробовать 10 минут',
#        'timestamp': '1470768562.001288',
#        'ts': 1470768562,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U1FLG6YR1> но топик модель - это же способ снижения размерности, потом все равно что-то с векторами делать',
#        'timestamp': '1470768713.001289',
#        'ts': 1470768713,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U1BAKQH2M>: да сорян, я чот глюканул и прочитал как k-nearest',
#        'timestamp': '1470768749.00129',
#        'ts': 1470768749,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 1,
#          'name': 'heavy_plus_sign',
#          'users': ['U1FLG6YR1']}],
#        'text': 'кстати k means по векторам из топик моделинга норм работает,  проверено ',
#        'timestamp': '1470768841.001292',
#        'ts': 1470768841,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': 'а сколько топиков для такого количества категорий выделять?',
#        'timestamp': '1470769073.001293',
#        'ts': 1470769073,
#        'type': 'message',
#        'user': 'U040M0W0S',
#        'user_real_name': 'i'},
#       {'channel': 'C047H3DP4',
#        'text': ' Несколько наборов, мне кажется',
#        'timestamp': '1470769120.001294',
#        'ts': 1470769120,
#        'type': 'message',
#        'user': 'U1FLG6YR1',
#        'user_real_name': 'hushpar'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470769293.000000', 'user': 'U0AS548A1'},
#        'reactions': [{'count': 1, 'name': 'grammar', 'users': ['U041LH06L']}],
#        'text': '<@U1BAKQH2M>: а чем топинг моделинг делал?',
#        'timestamp': '1470769128.001295',
#        'ts': 1470769128,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U1FLG6YR1>: наборов? это как?',
#        'timestamp': '1470769145.001296',
#        'ts': 1470769145,
#        'type': 'message',
#        'user': 'U040M0W0S',
#        'user_real_name': 'i'},
#       {'channel': 'C047H3DP4',
#        'text': 'просто интересно, что если svd, то потом kmeans конечно будет хорошо работать, потому что мы сначала сжали как-будто мы нормально распределены, а потом используем метод который на это опирается',
#        'timestamp': '1470769183.001297',
#        'ts': 1470769183,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'Это когда корпус из разного количества топиков',
#        'timestamp': '1470769251.001298',
#        'ts': 1470769251,
#        'type': 'message',
#        'user': 'U1FLG6YR1',
#        'user_real_name': 'hushpar'},
#       {'channel': 'C047H3DP4',
#        'text': 'Можно даже в разных моделях',
#        'timestamp': '1470769261.001299',
#        'ts': 1470769261,
#        'type': 'message',
#        'user': 'U1FLG6YR1',
#        'user_real_name': 'hushpar'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0AS548A1>: lda',
#        'timestamp': '1470769556.001301',
#        'ts': 1470769556,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470769721.000000', 'user': 'U0FL6RNHM'},
#        'text': '<@U1BAKQH2M>: хм, а как ты предлагаешь оценивать вероятность принадлежности к классу? точнее к кластеру, и как принимать решение о том, что объект не входит ни в один класс',
#        'timestamp': '1470769666.001302',
#        'ts': 1470769666,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну если кминс - то к какому центроиду ближе',
#        'timestamp': '1470769719.001304',
#        'ts': 1470769719,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': 'вероятность?',
#        'timestamp': '1470769746.001306',
#        'ts': 1470769746,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'можно, конечно, придумать какую-то эвристику.. но это так себе',
#        'timestamp': '1470769798.001307',
#        'ts': 1470769798,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'можно лог регресиию потом кинуть на фичу расстояние до каждого кластера',
#        'timestamp': '1470769810.001308',
#        'ts': 1470769810,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'будет вероятность',
#        'timestamp': '1470769813.001309',
#        'ts': 1470769813,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'есть еще всякие поправки которые немного хитрее это делать',
#        'timestamp': '1470769830.00131',
#        'ts': 1470769830,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'про svm можно загуглить',
#        'timestamp': '1470769841.001311',
#        'ts': 1470769841,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'но в общем они тоже кидают логрегрессию)',
#        'timestamp': '1470769850.001312',
#        'ts': 1470769850,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну там такие эвристики..',
#        'timestamp': '1470769899.001313',
#        'ts': 1470769899,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': '<http://scikit-learn.org/stable/modules/calibration.html>',
#        'timestamp': '1470769907.001314',
#        'ts': 1470769907,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1470769954.000000', 'user': 'U0FL6RNHM'},
#        'text': 'это, я что-то не очень понимаю, как в такой задаче поможет топик моделлинг, можете пояснить? То есть мне даже кажется, что здесь он бесполезен',
#        'timestamp': '1470769937.001315',
#        'ts': 1470769937,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'зажали фичи в топики',
#        'timestamp': '1470769954.001317',
#        'ts': 1470769954,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'логрегрессия - сложно, можно сделать что-нибудь максимум тупое, тип отнормировать вектор из обратных расстояний',
#        'timestamp': '1470769967.001318',
#        'ts': 1470769967,
#        'type': 'message',
#        'user': 'U1BAKQH2M',
#        'user_real_name': 'kiselev1189'},
#       {'channel': 'C047H3DP4',
#        'text': 'а потом на принадлежность к топику кминс классификация',
#        'timestamp': '1470769970.001319',
#        'ts': 1470769970,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'вот уж сложно)',
#        'timestamp': '1470769979.00132',
#        'ts': 1470769979,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0AS548A1>: ну то есть это что-то типа иерархической классификации?',
#        'timestamp': '1470769996.001321',
#        'ts': 1470769996,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'я бы так не сказал',
#        'timestamp': '1470770004.001322',
#        'ts': 1470770004,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну а чем это отличается от нее? сначала классифицируем с хорошей точностью на более крупные классы, далее, внутри класса уже пытаемся дальше классифицировать',
#        'timestamp': '1470770063.001323',
#        'ts': 1470770063,
#        'type': 'message',
#        'user': 'U0FL6RNHM',
#        'user_real_name': 'avasilev'},
#       {'channel': 'C047H3DP4',
#        'text': 'тем что сначала кластеризация',
#        'timestamp': '1470770076.001324',
#        'ts': 1470770076,
#        'type': 'message',
#        'user': 'U0AS548A1',
#        'user_real_name': 'evgeniiegorov'},
#       {'channel': 'C047H3DP4',
# ...
#        'text': 'Это вообще что такое? Давно оно там появилось? ',
#        'timestamp': '1466766183.000509',
#        'ts': 1466766183,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1466766275.000000', 'user': 'U0JHK9001'},
#        'text': 'дак по ссылке есть все, это как dropout в сетках',
#        'timestamp': '1466766259.00051',
#        'ts': 1466766259,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': 'появилось пару недель назад',
#        'timestamp': '1466766286.000512',
#        'ts': 1466766286,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': 'Jun 08, 2016\nadd Dart booster (#1220)\n\n',
#        'timestamp': '1466766332.000513',
#        'ts': 1466766332,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': 'Там в 1220 ссылка на пример даже есть',
#        'timestamp': '1466766424.000514',
#        'ts': 1466766424,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0DA4J82H>: там вроде так: обучил несколько деревьев, потом херак и выпилил одно (несколько аля лес). И пересчитал ленин рейт заново. Это на Брейн демедж еще похоже. Типа ансамбль становится менее жадный',
#        'timestamp': '1466771559.000515',
#        'ts': 1466771559,
#        'type': 'message',
#        'user': 'U1CF4A6BT',
#        'user_real_name': 'pwf'},
#       {'channel': 'C047H3DP4',
#        'text': 'А что за brain damage такой? ',
#        'timestamp': '1466771665.000516',
#        'ts': 1466771665,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': 'Вот этот, наверное: <http://yann.lecun.com/exdb/publis/pdf/lecun-90b.pdf>',
#        'timestamp': '1466771715.000517',
#        'ts': 1466771715,
#        'type': 'message',
#        'user': 'U04ELQZAU',
#        'user_real_name': 'asobolev'},
#       {'channel': 'C047H3DP4',
#        'text': 'Вопрос в тему XGB. Был у кого-нибудь опыт запиливания кастомной objective function. В частности интересует такие цели, где надо расщипить выборку наилучшими образом. Ну там information gain или KL divergence?',
#        'timestamp': '1466771748.000518',
#        'ts': 1466771748,
#        'type': 'message',
#        'user': 'U1CF4A6BT',
#        'user_real_name': 'pwf'},
#       {'channel': 'C047H3DP4',
#        'text': '&gt; optimal brain damage\nзвучит страшно',
#        'timestamp': '1466771776.000519',
#        'ts': 1466771776,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U04ELQZAU>: угу. Майорпейнишь сетку и та становится жоще и суровей!!',
#        'timestamp': '1466771842.00052',
#        'ts': 1466771842,
#        'type': 'message',
#        'user': 'U1CF4A6BT',
#        'user_real_name': 'pwf'},
#       {'channel': 'C047H3DP4',
#        'text': 'У нас на кафедре народ занимался похожей темой. Они с помощью ГА выращивали неподготовленные сети. Кстати и оптимизировали их тоже через ГА',
#        'timestamp': '1466771900.000521',
#        'ts': 1466771900,
#        'type': 'message',
#        'user': 'U1CF4A6BT',
#        'user_real_name': 'pwf'},
#       {'attachments': [{'author_icon': 'https://avatars.slack-edge.com/2016-05-28/46507692208_658f6dba3b0c4e44a7a2_48.jpg',
#          'author_link': 'https://opendatascience.slack.com/team/pwf',
#          'author_name': 'Владимир Первушин',
#          'author_subname': 'pwf',
#          'channel_id': 'C047H3DP4',
#          'channel_name': 'theory_and_practice',
#          'fallback': '[June 24th, 2016 5:35 AM] pwf: Вопрос в тему XGB. Был у кого-нибудь опыт запиливания кастомной objective function. В частности интересует такие цели, где надо расщипить выборку наилучшими образом. Ну там information gain или KL divergence?',
#          'footer': 'Posted in #theory_and_practice',
#          'from_url': 'https://opendatascience.slack.com/archives/theory_and_practice/p1466771748000518',
#          'id': 1,
#          'is_msg_unfurl': True,
#          'mrkdwn_in': ['text'],
#          'text': 'Вопрос в тему XGB. Был у кого-нибудь опыт запиливания кастомной objective function. В частности интересует такие цели, где надо расщипить выборку наилучшими образом. Ну там information gain или KL divergence?',
#          'ts': 1466771748.000518}],
#        'channel': 'C047H3DP4',
#        'text': '<https://opendatascience.slack.com/archives/theory_and_practice/p1466771748000518>\n\nА с этим же обычные деревья могут справиться',
#        'timestamp': '1466771930.000522',
#        'ts': 1466771930,
#        'type': 'message',
#        'user': 'U0DA4J82H',
#        'user_real_name': 'ololo'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U0DA4J82H>: Ну да. Просто у меня критерий хитрый. У меня бинарная классификация. Где надо предсказать условную вероятность. Тоесть есть еще одна фича, которую нельзя показывать модели, она является условием. И мне надо предсказать лейбл при условии, что эта фича чему-то равна',
#        'timestamp': '1466772817.000524',
#        'ts': 1466772817,
#        'type': 'message',
#        'user': 'U1CF4A6BT',
#        'user_real_name': 'pwf'}],
#      'title': 'пытался тут найти информацию про external memory в xgboost, а нашёл новый подвид деревьев\nкто-нибудь пробовал уже? \n<https://github.com/dmlc/xgboost/issues/809>\n<https://github.com/dmlc/xgboost/blob/7cfeb5f0122e76de3581cdcb542dcf2b9202aae9/doc/parameter.md>',
#      'ts': 1466764681000},
#     '_type': 'thread'},
#    {'_id': 'AVwqss0SXdpNESzK4vHX',
#     '_index': 'ods-slack-index',
#     '_score': 26.120924,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'text': 'xgboost лучше работает на неглубоких деревьях, а как на счет количества признаков? лучше больше нагенерить?',
#        'timestamp': '1461792136.000735',
#        'ts': 1461792136,
#        'type': 'message',
#        'user': 'U107256SG',
#        'user_real_name': 'joker'},
#       {'channel': 'C047H3DP4',
#        'text': 'Откуда инфа, что лучше на неглубоких?',
#        'timestamp': '1461792183.000736',
#        'ts': 1461792183,
#        'type': 'message',
#        'user': 'U04422XJL',
#        'user_real_name': 'mtrofimov'},
#       {'channel': 'C047H3DP4',
#        'text': 'читал где-то',
#        'timestamp': '1461792216.000737',
#        'ts': 1461792216,
#        'type': 'message',
#        'user': 'U107256SG',
#        'user_real_name': 'joker'},
#       {'channel': 'C047H3DP4',
#        'text': 'Есть и другая статья -- о том, что лучше деревья делать как раз глубокими и усреднять несколько бустингов',
#        'timestamp': '1461792251.000738',
#        'ts': 1461792251,
#        'type': 'message',
#        'user': 'U04422XJL',
#        'user_real_name': 'mtrofimov'},
#       {'channel': 'C047H3DP4',
#        'text': 'от датасета же зависит и характера данных очень сильно',
#        'timestamp': '1461792460.000739',
#        'ts': 1461792460,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U04422XJL>: покажи',
#        'timestamp': '1461792462.00074',
#        'ts': 1461792462,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': 'как правило меньше чем у RF раза в два',
#        'timestamp': '1461792474.000741',
#        'ts': 1461792474,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'text': 'если нужно взаимодействия вытаскивать, то их без глубоких деревьев не вытащишь',
#        'timestamp': '1461792480.000742',
#        'ts': 1461792480,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': 'а вообще всякие кеглеры рекомендуют танцевать между 3 и 15 для глубины дерева в xgboost',
#        'timestamp': '1461792537.000743',
#        'ts': 1461792537,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': 'Гуглить нужно, схожу не помню',
#        'timestamp': '1461792802.000744',
#        'ts': 1461792802,
#        'type': 'message',
#        'user': 'U04422XJL',
#        'user_real_name': 'mtrofimov'},
#       {'channel': 'C047H3DP4',
#        'text': 'Дефолтный вариант -- это глубина 1-3, обычно везде это дл бустингов советуют',
#        'timestamp': '1461792846.000745',
#        'ts': 1461792846,
#        'type': 'message',
#        'user': 'U04422XJL',
#        'user_real_name': 'mtrofimov'},
#       {'channel': 'C047H3DP4',
#        'text': 'А опыт кэггла говорит что да, в 3-15 запросто может быть оптимум',
#        'timestamp': '1461792875.000746',
#        'ts': 1461792875,
#        'type': 'message',
#        'user': 'U04422XJL',
#        'user_real_name': 'mtrofimov'},
#       {'channel': 'C047H3DP4',
#        'edited': {'ts': '1461792933.000000', 'user': 'U0JHK9001'},
#        'text': 'ну я где-то читал, что если датасет очень большой, то можно и 20 попробовать, но это не так уж и глубоко, если с RF сравнивать',
#        'timestamp': '1461792907.000747',
#        'ts': 1461792907,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 1,
#          'name': 'thinking_face',
#          'users': ['U0JHK9001']}],
#        'text': 'вся суть во взаимодействиях и том, как их вытащить. если с глубиной в 20 в листьях будет 100+ точек, то можно и такую глубину оставлять. основная проблема с глубокими деревьями в том, что они углубляются, "зарываясь" в данные и оставляя все меньше точек для нормальной оценки целевой переменной в листе',
#        'timestamp': '1461793055.000751',
#        'ts': 1461793055,
#        'type': 'message',
#        'user': 'U040HKJE7',
#        'user_real_name': 'natekin'},
#       {'channel': 'C047H3DP4',
#        'text': 'а вообще, может так сложится что в твоих данных взаимодействий глубже 2 просто нет :simple_smile:',
#        'timestamp': '1461793082.000752',
#        'ts': 1461793082,
#        'type': 'message',
#        'user': 'U040HKJE7',
#        'user_real_name': 'natekin'},
#       {'channel': 'C047H3DP4',
#        'text': 'как хинт, на infinite mnist (аугментированный до миллионов точек) и rf и xgboost работают сравнимо с глубокими нейронками',
#        'timestamp': '1461793325.000753',
#        'ts': 1461793325,
#        'type': 'message',
#        'user': 'U040HKJE7',
#        'user_real_name': 'natekin'},
#       {'channel': 'C047H3DP4',
#        'text': 'это делается min child weight и min sample split параметрами же',
#        'timestamp': '1461793359.000754',
#        'ts': 1461793359,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': 'говоришь тому же xgboost’y или random forest’y чтобы не фитил одну точку',
#        'timestamp': '1461793379.000755',
#        'ts': 1461793379,
#        'type': 'message',
#        'user': 'U065VP6F7',
#        'user_real_name': 'libfun'},
#       {'channel': 'C047H3DP4',
#        'text': 'ага, тогда если данных мало, он просто не будет новые сплиты строить (и шанс на оверфиттинг будет меньше)',
#        'timestamp': '1461793432.000756',
#        'ts': 1461793432,
#        'type': 'message',
#        'user': 'U040HKJE7',
#        'user_real_name': 'natekin'},
#       {'channel': 'C047H3DP4',
#        'text': 'если много, но сплиты слабые, то есть `gamma` ещё',
#        'timestamp': '1461793587.000757',
#        'ts': 1461793587,
#        'type': 'message',
#        'user': 'U0JHK9001',
#        'user_real_name': 'rushter'}],
#      'title': 'xgboost лучше работает на неглубоких деревьях, а как на счет количества признаков? лучше больше нагенерить?',
#      'ts': 1461792136000},
#     '_type': 'thread'},
#    {'_id': 'AVwqsstbXdpNESzK4vFv',
#     '_index': 'ods-slack-index',
#     '_score': 25.972761,
#     '_source': {'channel': 'theory_and_practice',
#      'messages': [{'channel': 'C047H3DP4',
#        'text': 'Xgboost быстрее h2o?) разве что при небольшом объеме данных, не?',
#        'timestamp': '1453455726.001491',
#        'ts': 1453455726,
#        'type': 'message',
#        'user': 'U0JTMFHDE',
#        'user_real_name': 'ivantrusov'},
#       {'channel': 'C047H3DP4',
#        'text': 'на спарс матрице шириной в 7м и высотой в 15-20м хгбуст отлично работает',
#        'timestamp': '1453455927.001492',
#        'ts': 1453455927,
#        'type': 'message',
#        'user': 'U06J1LG1M',
#        'user_real_name': 'mephistopheies'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U06J1LG1M>: и на какой тачке?',
#        'timestamp': '1453455943.001493',
#        'ts': 1453455943,
#        'type': 'message',
#        'user': 'U041SH27M',
#        'user_real_name': 'lolpig'},
#       {'channel': 'C047H3DP4',
#        'text': 'да дно а не тачка',
#        'timestamp': '1453455953.001494',
#        'ts': 1453455953,
#        'type': 'message',
#        'user': 'U06J1LG1M',
#        'user_real_name': 'mephistopheies'},
#       {'channel': 'C047H3DP4',
#        'text': '200гб рам и 24 ядра',
#        'timestamp': '1453455963.001495',
#        'ts': 1453455963,
#        'type': 'message',
#        'user': 'U06J1LG1M',
#        'user_real_name': 'mephistopheies'},
#       {'channel': 'C047H3DP4',
#        'text': 'я на такой даже в фолаут играть не стал бы',
#        'timestamp': '1453455975.001496',
#        'ts': 1453455975,
#        'type': 'message',
#        'user': 'U06J1LG1M',
#        'user_real_name': 'mephistopheies'},
#       {'channel': 'C047H3DP4',
#        'text': 'как <@U040HKJE7> рассказал про свой зоопарк с 2тб рам,  я  теперь к своим отношусь снисходительно',
#        'timestamp': '1453456002.001497',
#        'ts': 1453456002,
#        'type': 'message',
#        'user': 'U06J1LG1M',
#        'user_real_name': 'mephistopheies'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 3,
#          'name': 'bike',
#          'users': ['U09JEC7V0', 'U041SH27M', 'U0JTMFHDE']}],
#        'text': '<@U0JTMFHDE>: глянь, на каких "ведрах" посоны в мейле и делойте гоняют. Даже жалко их стало чота.',
#        'timestamp': '1453456189.0015',
#        'ts': 1453456189,
#        'type': 'message',
#        'user': 'U041LH06L',
#        'user_real_name': 'semenoffalex'},
#       {'channel': 'C047H3DP4',
#        'text': 'понабрали по объявлениям',
#        'timestamp': '1453457047.001501',
#        'ts': 1453457047,
#        'type': 'message',
#        'user': 'U041SH27M',
#        'user_real_name': 'lolpig'},
#       {'channel': 'C047H3DP4',
#        'text': '<@U041SH27M>: зависть -- плохое чувство!',
#        'timestamp': '1453457256.001502',
#        'ts': 1453457256,
#        'type': 'message',
#        'user': 'U041LH06L',
#        'user_real_name': 'semenoffalex'},
#       {'channel': 'C047H3DP4',
#        'text': 'ну я тут сижу на 8 ядрах, что считай почти как на домашнем компе',
#        'timestamp': '1453457286.001504',
#        'ts': 1453457286,
#        'type': 'message',
#        'user': 'U041SH27M',
#        'user_real_name': 'lolpig'},
#       {'channel': 'C047H3DP4',
#        'reactions': [{'count': 3,
#          'name': 'loh',
#          'users': ['U041P485A', 'U0JTMFHDE', 'U041SH27M']}],
#        'text': 'Какой там код у смайлика "как лох"?',
#        'timestamp': '1453457370.001505',
#        'ts': 1453457370,
#        'type': 'message',
#        'user': 'U041LH06L',
#        'user_real_name': 'semenoffalex'},
#       {'channel': 'C047H3DP4',
#        'text': 'В пчелке хороший кластер кстати)',
#        'timestamp': '1453457408.001506',
#        'ts': 1453457408,
#        'type': 'message',
#        'user': 'U0JTMFHDE',
#        'user_real_name': 'ivantrusov'}],
#      'title': 'Xgboost быстрее h2o?) разве что при небольшом объеме данных, не?',
#      'ts': 1453455726000},
#     '_type': 'thread'}],
#   'max_score': 46.286835,
#   'total': 970},
#  'timed_out': False,
#  'took': 12}
