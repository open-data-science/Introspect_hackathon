# %%
import pandas as pd
import numpy as np

from tqdm import tqdm_notebook

import gc
from multiprocessing import Pool

# %%
df = pd.read_csv('../../data/ods_dump/imported_message_fixed2.csv')
users = pd.read_csv('../../data/ods_dump/imported_user_data.csv')

# %%
#df.head()
users.shape
# Out:
# (11159, 34)

# %%
#df['user'].nunique()
users['id'].nunique()
# Out:
# 11159

# %%
users
# Out:
#               id            name  deleted                   tz  \
# 0      U4EMUGFNG               0        0       Asia/Jerusalem
# 1      U7SE7ANCW        00serd00        0     Asia/Vladivostok
# 2      U6YSPBJK0       012345vov        0          Asia/Kuwait
# 3      U8YE1BVPS          04ok11        0      Europe/Helsinki
# 4      U6U25UP96           0xdev        0         Europe/Minsk
# 5      U8Y1JEXU4       0xk175un3        0        Europe/Moscow
# 6      U7527KGCX      100hzjugin        0          Asia/Kuwait
# 7      U8Y8TM8HF            10ka        0        Europe/Moscow
# 8      U95NYFKQU          11812r        0         Asia/Kolkata
# 9      U6ZK44Z53         13torch        0        Europe/Moscow
# 10     U8ME1E8HY         1997_29        0  America/Los_Angeles
# 11     U93V5EZ9P      19chebakov        0        Europe/Moscow
# 12     U054CQTS7       1aguschin        0        Europe/Athens
# 13     U7CS0D7T8     1ce.mironov        0          Asia/Kuwait
# ...

# %%
# %%time

list_of_sum_mention = []

for user in tqdm_notebook(users['id'][:15]):
    sum_mention = df.apply(lambda x: 1 if user in str(x) else 0).sum()
    list_of_sum_mention = np.append(list_of_sum_mention, sum_mention)
# Out:
# ...
# Exception in thread Thread-16:
# Traceback (most recent call last):
#   File "/Library/anaconda3/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/Library/anaconda3/lib/python3.6/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/Library/anaconda3/lib/python3.6/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# CPU times: user 12.9 s, sys: 730 ms, total: 13.6 s
# Wall time: 15.1 s

# %%
df=df.fillna('')['text']

# %%
p=multiprocessing.Pool(8)
gc.collect()
# Out:
# 94

# %%
def f(x):
    return  df.str.contains(x).sum()

# %%
# %%time
res=p.map(f,users['id'].values)
# Out:
# CPU times: user 30 s, sys: 13.3 s, total: 43.2 s
# Wall time: 1h 31min 46s

# %%
res
# Out:
# [19,
#  0,
#  10,
#  0,
#  16,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  107,
#  0,
#  13,
#  12,
#  0,
#  28,
#  20,
#  12,
#  0,
#  0,
#  0,
#  2,
#  0,
#  0,
#  0,
#  10,
#  10,
#  0,
#  40,
#  13,
#  0,
#  181,
#  29,
#  18,
#  0,
#  0,
#  0,
#  0,
#  0,
#  14,
#  0,
#  0,
#  18,
#  11,
#  13,
#  14,
#  16,
#  27,
#  14,
#  11,
#  13,
#  15,
#  12,
#  15,
#  1,
#  0,
#  0,
#  0,
#  11,
#  0,
#  0,
#  0,
#  0,
#  0,
#  0,
#  2,
#  11,
#  23,
#  12,
#  0,
#  0,
#  0,
#  2,
#  0,
#  0,
#  4,
#  0,
#  0,
#  0,
#  20,
#  16,
#  10,
#  0,
#  6,
#  14,
#  13,
#  0,
#  13,
#  0,
#  0,
#  15,
#  0,
#  11,
#  11,
#  0,
#  0,
#  0,
#  20,
#  11,
#  12,
#  15,
#  0,
#  0,
#  0,
#  41,
#  0,
#  14,
#  15,
#  0,
#  13,
#  0,
#  0,
#  1,
#  49,
#  0,
#  21,
#  20,
#  0,
#  14,
#  21,
#  0,
#  0,
#  9,
#  23,
#  0,
#  12,
#  0,
#  15,
#  2,
#  0,
#  0,
#  75,
#  0,
#  0,
#  17,
#  40,
#  15,
#  0,
#  0,
#  0,
#  38,
#  0,
#  14,
#  0,
#  14,
#  0,
#  0,
#  23,
#  15,
#  23,
#  24,
#  0,
# ...

# %%
users['mentioned'] = res

# %%
users[['id', 'mentioned']].to_csv('../../data/ods_dump/mention_users.csv', index=False)

# %%
users[users['id'] == 'U040HKJE7']['mentioned']
# Out:
# 6963    3708
# Name: mentioned, dtype: int64

# %%
pd.read_csv('../../data/ods_dump/habrahabr.csv')
# Out:
#                  nick_name;id
# 0          jandevel;U6NG0K2BW
# 1          iggisv9t;U1UMQM200
# 2          Safronov;U6QBC2ERG
# 3         madrugado;U0K47J3HR
# 4      Skolopendriy;U044084RH
# 5          befuddle;U53DE74GZ
# 6             yorko;U1UNFRQ1K
# 7           Dumbris;U19VD9AQH
# 8           rakhlin;U6HFLJK7H
# 9          ogurtsov;U24FHECDD
# 10         johnkorn;U0L4KM9R9
# 11           grisme;U44A57Q1G
# 12     fall_out_bug;U3TF60E65
# 13         temakone;U59CPL6ES
# 14   mephistopheies;U06J1LG1M
# 15           Artgor;U4ZRFG1V0
# 16  danila_savenkov;U5R9LKKRS
# 17          ternaus;U34Q3KU8H
# 18        movchan74;U0ZJV6E5Q
# 19          natekin;U040HKJE7
# 20   egor_labintcev;U0ZHCGY5T
# 21           Ferres;U1LNBRZ29
# 22         spiralis;U0L4DGZU0
# 23           libfun;U065VP6F7
# 24      Arseny_Info;U1G303UTW
# 25       vradchenko;U0M39M6LS
# 26         miptgirl;U14DWNVNJ
# 27      sovcharenko;U041P485A
# 28          cotique;U14BPHDK6
# 29           couatl;U04CH4QBD
